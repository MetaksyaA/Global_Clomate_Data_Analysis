# %%
pip install googlemaps

# %%
import pandas as pd
import googlemaps
from time import sleep

# Initialize the Google Maps client with your API key
API_KEY = "AIzaSyCJadDlsp0FaVRU5tysFcgkFt9cO35OBAY"  # Replace with your actual API key
gmaps = googlemaps.Client(key=API_KEY)

# Sample data
file_path = r"C:\Users\User\Desktop\Final_project\GlobalWeatherRepository.csv"
data = pd.read_csv(file_path)

# Create a DataFrame
df = pd.DataFrame(data)
# Get unique latitude/longitude pairs
unique_coords = df[['latitude', 'longitude']].drop_duplicates()

# Function to reverse geocode using latitude and longitude with Google Maps API
def reverse_geocode(lat, lon):
    try:
        # Perform reverse geocoding
        result = gmaps.reverse_geocode((lat, lon))
        
        if result and len(result) > 0:
            # Extract the country from the result
            for component in result[0]['address_components']:
                if 'country' in component['types']:
                    return component['long_name']
        return None
    except Exception as e:
        print(f"Error: {e}")
        return None

# Dictionary to store reverse-geocoded country names
coord_to_country = {}

# Iterate over unique lat/lon pairs and reverse geocode them
for index, row in unique_coords.iterrows():
    lat = row['latitude']
    lon = row['longitude']
    
    corrected_country = reverse_geocode(lat, lon)
    
    if corrected_country:
        print(f"Reverse geocoded: ({lat}, {lon}) -> {corrected_country}")
        coord_to_country[(lat, lon)] = corrected_country
    else:
        print(f"Failed to reverse geocode: ({lat}, {lon})")
    
    # Add a delay to avoid hitting the rate limit
    sleep(0.2)

# Map the corrected country names back to the original DataFrame
df['corrected_country'] = df.apply(lambda row: coord_to_country.get((row['latitude'], row['longitude']), row['country']), axis=1)

# Print the updated DataFrame
print("\nUpdated DataFrame:")
print(df)
# Out:
# Reverse geocoded: (34.52, 69.18) -> Afghanistan
# Reverse geocoded: (41.33, 19.82) -> Albania
# Reverse geocoded: (36.76, 3.05) -> Algeria
# Reverse geocoded: (42.5, 1.52) -> Andorra
# Reverse geocoded: (-8.84, 13.23) -> Angola
# Reverse geocoded: (17.12, -61.85) -> Antigua and Barbuda
# Reverse geocoded: (-34.59, -58.67) -> Argentina
# Reverse geocoded: (40.18, 44.51) -> Armenia
# Reverse geocoded: (-35.28, 149.22) -> Australia
# Reverse geocoded: (48.2, 16.37) -> Austria
# Reverse geocoded: (40.4, 49.88) -> Azerbaijan
# Reverse geocoded: (25.08, -77.35) -> The Bahamas
# Reverse geocoded: (26.24, 50.58) -> Bahrain
# Reverse geocoded: (23.72, 90.41) -> Bangladesh
# Reverse geocoded: (13.1, -59.62) -> Barbados
# Reverse geocoded: (53.9, 27.57) -> Belarus
# Reverse geocoded: (50.83, 4.33) -> Belgium
# Reverse geocoded: (17.25, -88.77) -> Belize
# Reverse geocoded: (6.48, 2.62) -> Benin
# Reverse geocoded: (27.48, 89.6) -> Bhutan
# Reverse geocoded: (-19.04, -65.26) -> Bolivia
# Reverse geocoded: (43.85, 18.38) -> Bosnia and Herzegovina
# Reverse geocoded: (-24.65, 25.91) -> Botswana
# Reverse geocoded: (-2.08, -58.17) -> Brazil
# Reverse geocoded: (4.88, 114.93) -> Brunei
# Reverse geocoded: (42.68, 23.32) -> Bulgaria
# Reverse geocoded: (12.37, -1.52) -> Burkina Faso
# Reverse geocoded: (-3.38, 29.36) -> Burundi
# Reverse geocoded: (-24.37, 46.45) -> Madagascar
# Reverse geocoded: (14.93, -23.51) -> Cabo Verde
# Reverse geocoded: (11.55, 104.92) -> Cambodia
# Reverse geocoded: (3.87, 11.52) -> Cameroon
# Reverse geocoded: (45.42, -75.7) -> Canada
# Reverse geocoded: (4.37, 18.58) -> Central African Republic
# Reverse geocoded: (12.11, 15.05) -> Chad
# Reverse geocoded: (-33.45, -70.67) -> Chile
# Reverse geocoded: (39.93, 116.39) -> China
# Reverse geocoded: (43.32, 24.7) -> Bulgaria
# Reverse geocoded: (-11.7, 43.24) -> Comoros
# Reverse geocoded: (-4.26, 15.28) -> Republic of the Congo
# Reverse geocoded: (9.97, -84.08) -> Costa Rica
# Reverse geocoded: (45.8, 16.0) -> Croatia
# Reverse geocoded: (23.13, -82.36) -> Cuba
# Reverse geocoded: (35.17, 33.37) -> Cyprus
# Reverse geocoded: (50.08, 14.47) -> Czechia
# Reverse geocoded: (-4.3, 15.3) -> Democratic Republic of the Congo
# Reverse geocoded: (55.67, 12.58) -> Denmark
# Reverse geocoded: (11.6, 43.15) -> Djibouti
# Failed to reverse geocode: (15.3, -61.4)
# Reverse geocoded: (18.47, -69.9) -> Dominican Republic
# Reverse geocoded: (-0.22, -78.5) -> Ecuador
# Reverse geocoded: (30.05, 31.25) -> Egypt
# Reverse geocoded: (13.71, -89.2) -> El Salvador
# Reverse geocoded: (3.75, 8.78) -> Equatorial Guinea
# Reverse geocoded: (15.33, 38.93) -> Eritrea
# Reverse geocoded: (59.43, 24.73) -> Estonia
# Reverse geocoded: (-26.32, 31.13) -> Eswatini
# Reverse geocoded: (9.03, 38.7) -> Ethiopia
# Reverse geocoded: (-18.13, 178.42) -> Fiji
# Reverse geocoded: (60.18, 24.93) -> Finland
# Reverse geocoded: (48.87, 2.33) -> France
# Reverse geocoded: (0.38, 9.45) -> Gabon
# Reverse geocoded: (13.45, -16.58) -> The Gambia
# Reverse geocoded: (41.73, 44.79) -> Georgia
# Reverse geocoded: (52.52, 13.4) -> Germany
# Reverse geocoded: (5.55, -0.22) -> Ghana
# Reverse geocoded: (37.98, 23.72) -> Greece
# Reverse geocoded: (12.05, -61.75) -> Grenada
# Reverse geocoded: (14.62, -90.53) -> Guatemala
# Reverse geocoded: (9.51, -13.71) -> Guinea
# Reverse geocoded: (11.85, -15.58) -> Guinea-Bissau
# Reverse geocoded: (6.8, -58.17) -> Guyana
# Reverse geocoded: (18.54, -72.34) -> Haiti
# Reverse geocoded: (41.9, 12.45) -> Italy
# Reverse geocoded: (14.1, -87.22) -> Honduras
# Reverse geocoded: (47.5, 19.08) -> Hungary
# Reverse geocoded: (63.83, -22.43) -> Iceland
# Reverse geocoded: (28.6, 77.2) -> India
# Reverse geocoded: (-6.21, 106.85) -> Indonesia
# Reverse geocoded: (35.73, 51.33) -> Iran
# Reverse geocoded: (33.34, 44.39) -> Iraq
# Reverse geocoded: (53.33, -6.25) -> Ireland
# Failed to reverse geocode: (31.78, 35.23)
# Reverse geocoded: (41.9, 12.48) -> Italy
# Reverse geocoded: (17.97, -76.75) -> Jamaica
# Reverse geocoded: (35.69, 139.69) -> Japan
# Reverse geocoded: (31.95, 35.93) -> Jordan
# Reverse geocoded: (51.18, 71.43) -> Kazakhstan
# Reverse geocoded: (-1.28, 36.82) -> Kenya
# Reverse geocoded: (-0.88, 169.53) -> Kiribati
# Reverse geocoded: (29.37, 47.96) -> Kuwait
# Reverse geocoded: (42.87, 74.6) -> Kyrgyzstan
# Reverse geocoded: (-8.18, 114.32) -> Indonesia
# Reverse geocoded: (56.95, 24.1) -> Latvia
# Reverse geocoded: (33.87, 35.51) -> Lebanon
# Reverse geocoded: (-29.32, 27.48) -> Lesotho
# Reverse geocoded: (6.31, -10.8) -> Liberia
# Reverse geocoded: (18.78, 100.78) -> Thailand
# Reverse geocoded: (47.13, 9.52) -> Liechtenstein
# Reverse geocoded: (54.68, 25.32) -> Lithuania
# Reverse geocoded: (49.61, 6.13) -> Luxembourg
# Reverse geocoded: (-18.92, 47.52) -> Madagascar
# Reverse geocoded: (-13.98, 33.78) -> Malawi
# Reverse geocoded: (3.17, 101.7) -> Malaysia
# Reverse geocoded: (3.48, 73.53) -> Maldives
# Reverse geocoded: (12.65, -8.0) -> Mali
# Reverse geocoded: (35.9, 14.51) -> Malta
# Reverse geocoded: (7.1, 171.38) -> Marshall Islands
# Reverse geocoded: (18.09, -15.98) -> Mauritania
# Reverse geocoded: (-20.16, 57.5) -> Mauritius
# Reverse geocoded: (19.43, -99.13) -> Mexico
# Reverse geocoded: (6.92, 158.15) -> Micronesia
# Reverse geocoded: (36.26, 46.59) -> Iran
# Reverse geocoded: (43.73, 7.42) -> Monaco
# Reverse geocoded: (47.92, 106.92) -> Mongolia
# Reverse geocoded: (42.44, 19.26) -> Montenegro
# Reverse geocoded: (34.03, -6.84) -> Morocco
# Reverse geocoded: (-25.97, 32.59) -> Mozambique
# Reverse geocoded: (16.78, 94.73) -> Myanmar (Burma)
# Reverse geocoded: (-22.57, 17.08) -> Namibia
# Reverse geocoded: (39.55, 27.62) -> Türkiye
# Reverse geocoded: (27.72, 85.32) -> Nepal
# Reverse geocoded: (52.37, 4.89) -> Netherlands
# Reverse geocoded: (-41.3, 174.78) -> New Zealand
# Reverse geocoded: (12.15, -86.27) -> Nicaragua
# Reverse geocoded: (13.52, 2.12) -> Niger
# Reverse geocoded: (9.18, 7.18) -> Nigeria
# Reverse geocoded: (39.02, 125.75) -> North Korea
# Reverse geocoded: (42.0, 21.43) -> North Macedonia
# Reverse geocoded: (59.92, 10.75) -> Norway
# Reverse geocoded: (23.61, 58.59) -> Oman
# Reverse geocoded: (33.7, 73.17) -> Pakistan
# Reverse geocoded: (7.35, 134.45) -> Palau
# Reverse geocoded: (-11.18, -67.08) -> Bolivia
# Reverse geocoded: (8.97, -79.53) -> Panama
# Reverse geocoded: (-9.46, 147.19) -> Papua New Guinea
# Reverse geocoded: (-19.45, -61.15) -> Bolivia
# Reverse geocoded: (-12.05, -77.05) -> Peru
# Reverse geocoded: (14.6, 120.98) -> Philippines
# Reverse geocoded: (52.25, 21.0) -> Poland
# Reverse geocoded: (38.72, -9.13) -> Portugal
# Reverse geocoded: (25.29, 51.53) -> Qatar
# Reverse geocoded: (44.43, 26.1) -> Romania
# Reverse geocoded: (55.75, 37.62) -> Russia
# Reverse geocoded: (-1.95, 30.06) -> Rwanda
# Reverse geocoded: (17.3, -62.72) -> Saint Kitts and Nevis
# Reverse geocoded: (14.0, -61.0) -> Saint Lucia
# Reverse geocoded: (13.13, -61.22) -> Saint Vincent and the Grenadines
# Reverse geocoded: (-13.83, -171.73) -> Samoa
# Reverse geocoded: (43.93, 12.45) -> San Marino
# Reverse geocoded: (50.88, 2.98) -> Belgium
# Reverse geocoded: (24.64, 46.77) -> Saudi Arabia
# Reverse geocoded: (14.67, -17.44) -> Senegal
# Reverse geocoded: (44.8, 20.47) -> Serbia
# Reverse geocoded: (-4.62, 55.45) -> Seychelles
# Reverse geocoded: (8.49, -13.23) -> Sierra Leone
# Reverse geocoded: (1.29, 103.86) -> Singapore
# Reverse geocoded: (48.15, 17.12) -> Slovakia
# Reverse geocoded: (46.06, 14.51) -> Slovenia
# Reverse geocoded: (-9.43, 159.95) -> Solomon Islands
# Reverse geocoded: (2.07, 45.37) -> Somalia
# Reverse geocoded: (-25.75, 28.19) -> South Africa
# Reverse geocoded: (37.57, 127.0) -> South Korea
# Reverse geocoded: (12.15, 24.45) -> Sudan
# Reverse geocoded: (40.4, -3.68) -> Spain
# Reverse geocoded: (6.93, 79.85) -> Sri Lanka
# Reverse geocoded: (15.59, 32.53) -> Sudan
# Reverse geocoded: (5.83, -55.17) -> Suriname
# Reverse geocoded: (59.33, 18.05) -> Sweden
# Reverse geocoded: (46.92, 7.47) -> Switzerland
# Reverse geocoded: (33.5, 36.3) -> Syria
# Reverse geocoded: (38.56, 68.77) -> Tajikistan
# Reverse geocoded: (-6.18, 35.75) -> Tanzania
# Reverse geocoded: (13.75, 100.52) -> Thailand
# Reverse geocoded: (-8.56, 125.57) -> Timor-Leste
# Reverse geocoded: (43.81, 23.24) -> Bulgaria
# Reverse geocoded: (-21.13, -175.2) -> Tonga
# Reverse geocoded: (10.65, -61.52) -> Trinidad and Tobago
# Reverse geocoded: (36.8, 10.18) -> Tunisia
# Reverse geocoded: (39.93, 32.86) -> Türkiye
# Reverse geocoded: (37.95, 58.38) -> Turkmenistan
# Reverse geocoded: (-8.52, 179.22) -> Tuvalu
# Reverse geocoded: (0.32, 32.57) -> Uganda
# Reverse geocoded: (50.43, 30.52) -> Ukraine
# Reverse geocoded: (24.47, 54.37) -> United Arab Emirates
# Reverse geocoded: (51.52, -0.11) -> United Kingdom
# Reverse geocoded: (46.6, -120.49) -> United States
# Reverse geocoded: (-34.86, -56.17) -> Uruguay
# Reverse geocoded: (41.32, 69.25) -> Uzbekistan
# Reverse geocoded: (-17.73, 168.32) -> Vanuatu
# Reverse geocoded: (10.5, -66.92) -> Venezuela
# Reverse geocoded: (21.03, 105.85) -> Vietnam
# Reverse geocoded: (15.35, 44.21) -> Yemen
# Reverse geocoded: (-15.42, 28.28) -> Zambia
# Reverse geocoded: (-17.82, 31.04) -> Zimbabwe
# Reverse geocoded: (5.47, 10.42) -> Cameroon
# Reverse geocoded: (9.8, -84.17) -> Costa Rica
# Reverse geocoded: (16.78, 96.17) -> Myanmar (Burma)
# Reverse geocoded: (7.36, 134.51) -> Palau
# Reverse geocoded: (-21.55, -58.12) -> Paraguay
# Reverse geocoded: (51.25, 3.63) -> Belgium
# Reverse geocoded: (48.08, -123.04) -> United States
# Reverse geocoded: (7.32, 13.58) -> Cameroon
# Failed to reverse geocode: (63.37, -20.21)
# Reverse geocoded: (17.93, -76.85) -> Jamaica
# Reverse geocoded: (6.88, 73.1) -> Maldives
# Reverse geocoded: (7.33, 134.48) -> Palau
# Failed to reverse geocode: (-23.43, -61.33)
# Reverse geocoded: (59.13, 44.3) -> Russia
# Reverse geocoded: (21.13, 104.7) -> Vietnam
# Reverse geocoded: (59.89, 30.26) -> Russia
# Reverse geocoded: (-23.53, -46.62) -> Brazil
# Reverse geocoded: (-4.05, 39.67) -> Kenya
# Reverse geocoded: (4.05, 9.7) -> Cameroon
# Reverse geocoded: (4.6, -74.08) -> Colombia
# Reverse geocoded: (39.53, -111.59) -> United States
# Reverse geocoded: (33.78, -89.81) -> United States
# Reverse geocoded: (64.15, -21.95) -> Iceland
# Reverse geocoded: (40.71, -74.01) -> United States
# Reverse geocoded: (18.0, -76.8) -> Jamaica
# Reverse geocoded: (17.97, 102.6) -> Laos
# Reverse geocoded: (32.89, 13.18) -> Libya
# Reverse geocoded: (4.17, 73.5) -> Maldives
# Reverse geocoded: (10.75, 106.67) -> Vietnam
# Reverse geocoded: (-0.14, 98.19) -> Indonesia
# Reverse geocoded: (7.5, 134.57) -> Palau
# Failed to reverse geocode: (-25.27, -57.67)
# Failed to reverse geocode: (42.67, 21.17)
# Reverse geocoded: (-37.82, 144.97) -> Australia
# Reverse geocoded: (-7.25, 112.75) -> Indonesia
# Reverse geocoded: (6.13, 1.22) -> Togo
# Reverse geocoded: (4.63, 118.37) -> Malaysia
# Reverse geocoded: (-12.35, 43.85) -> Comoros
# Reverse geocoded: (6.43, -70.92) -> Colombia
# Reverse geocoded: (29.37, 47.98) -> Kuwait
# Reverse geocoded: (51.12, 17.53) -> Poland
# Reverse geocoded: (27.42, -109.93) -> Mexico
# Reverse geocoded: (53.33, 21.62) -> Poland
# Reverse geocoded: (31.63, -8.0) -> Morocco
# Reverse geocoded: (51.1, 4.75) -> Belgium
# Reverse geocoded: (37.7, 65.37) -> Turkmenistan
# Reverse geocoded: (38.85, 34.65) -> Türkiye
# Reverse geocoded: (7.36, 134.56) -> Palau
# Reverse geocoded: (34.5167, 69.1833) -> Afghanistan
# Reverse geocoded: (41.3275, 19.8189) -> Albania
# Reverse geocoded: (36.7631, 3.0506) -> Algeria
# Reverse geocoded: (42.5, 1.5167) -> Andorra
# Reverse geocoded: (-8.8383, 13.2344) -> Angola
# Reverse geocoded: (17.1167, -61.85) -> Antigua and Barbuda
# Reverse geocoded: (-34.5875, -58.6725) -> Argentina
# Reverse geocoded: (40.1811, 44.5136) -> Armenia
# Reverse geocoded: (-35.2833, 149.2167) -> Australia
# Reverse geocoded: (48.2, 16.3667) -> Austria
# Reverse geocoded: (40.3953, 49.8822) -> Azerbaijan
# Reverse geocoded: (25.0833, -77.35) -> The Bahamas
# Reverse geocoded: (26.2361, 50.5831) -> Bahrain
# Reverse geocoded: (23.7231, 90.4086) -> Bangladesh
# Reverse geocoded: (13.1, -59.6167) -> Barbados
# Reverse geocoded: (53.9, 27.5667) -> Belarus
# Reverse geocoded: (50.8333, 4.3333) -> Belgium
# Reverse geocoded: (17.25, -88.7667) -> Belize
# Reverse geocoded: (6.4833, 2.6167) -> Benin
# Reverse geocoded: (27.4833, 89.6) -> Bhutan
# Reverse geocoded: (-19.0431, -65.2592) -> Bolivia
# Reverse geocoded: (43.85, 18.3833) -> Bosnia and Herzegovina
# Reverse geocoded: (-24.6464, 25.9119) -> Botswana
# Reverse geocoded: (-2.0833, -58.1667) -> Brazil
# Reverse geocoded: (4.8833, 114.9333) -> Brunei
# Reverse geocoded: (42.6833, 23.3167) -> Bulgaria
# Reverse geocoded: (12.3703, -1.5247) -> Burkina Faso
# Reverse geocoded: (-3.3761, 29.36) -> Burundi
# Reverse geocoded: (-24.3667, 46.45) -> Madagascar
# Reverse geocoded: (14.9315, -23.5125) -> Cabo Verde
# Reverse geocoded: (11.55, 104.9167) -> Cambodia
# Reverse geocoded: (7.3167, 13.5833) -> Cameroon
# Reverse geocoded: (45.4167, -75.7) -> Canada
# Reverse geocoded: (4.3667, 18.5833) -> Central African Republic
# Reverse geocoded: (12.1131, 15.0492) -> Chad
# Reverse geocoded: (-33.45, -70.6667) -> Chile
# Reverse geocoded: (39.9289, 116.3883) -> China
# Reverse geocoded: (43.3167, 24.7) -> Bulgaria
# Reverse geocoded: (-11.7042, 43.2403) -> Comoros
# Reverse geocoded: (-4.2592, 15.2847) -> Republic of the Congo
# Reverse geocoded: (9.8, -84.1667) -> Costa Rica
# Reverse geocoded: (23.1319, -82.3642) -> Cuba
# Reverse geocoded: (35.1667, 33.3667) -> Cyprus
# Reverse geocoded: (50.0833, 14.4667) -> Czechia
# Reverse geocoded: (55.6667, 12.5833) -> Denmark
# Reverse geocoded: (11.595, 43.1481) -> Djibouti
# Reverse geocoded: (18.4667, -69.9) -> Dominican Republic
# Reverse geocoded: (-0.2167, -78.5) -> Ecuador
# Reverse geocoded: (13.7086, -89.2031) -> El Salvador
# Reverse geocoded: (3.75, 8.7833) -> Equatorial Guinea
# Reverse geocoded: (15.3333, 38.9333) -> Eritrea
# Reverse geocoded: (59.4339, 24.7281) -> Estonia
# Reverse geocoded: (-26.3167, 31.1333) -> Eswatini
# Reverse geocoded: (9.0333, 38.7) -> Ethiopia
# Reverse geocoded: (-18.1333, 178.4167) -> Fiji
# Reverse geocoded: (60.1756, 24.9342) -> Finland
# Reverse geocoded: (48.8667, 2.3333) -> France
# Reverse geocoded: (0.3833, 9.45) -> Gabon
# Reverse geocoded: (13.4531, -16.5775) -> The Gambia
# Reverse geocoded: (41.725, 44.7908) -> Georgia
# Reverse geocoded: (52.5167, 13.4) -> Germany
# Reverse geocoded: (5.55, -0.2167) -> Ghana
# Reverse geocoded: (37.9795, 23.7162) -> Greece
# Reverse geocoded: (14.6211, -90.5269) -> Guatemala
# Reverse geocoded: (9.5092, -13.7122) -> Guinea
# Reverse geocoded: (11.85, -15.5833) -> Guinea-Bissau
# Reverse geocoded: (6.8, -58.1667) -> Guyana
# Reverse geocoded: (18.5392, -72.335) -> Haiti
# Reverse geocoded: (41.904, 12.453) -> Vatican City
# Reverse geocoded: (14.1, -87.2167) -> Honduras
# Reverse geocoded: (47.5, 19.0833) -> Hungary
# Failed to reverse geocode: (63.365, -20.2075)
# Reverse geocoded: (-6.2146, 106.8451) -> Indonesia
# Reverse geocoded: (35.7261, 51.3304) -> Iran
# Reverse geocoded: (33.3386, 44.3939) -> Iraq
# Reverse geocoded: (53.3331, -6.2489) -> Ireland
# Reverse geocoded: (41.9, 12.4833) -> Italy
# Reverse geocoded: (17.9333, -76.85) -> Jamaica
# Reverse geocoded: (35.6895, 139.6917) -> Japan
# Reverse geocoded: (31.95, 35.9333) -> Jordan
# Reverse geocoded: (51.1811, 71.4278) -> Kazakhstan
# Reverse geocoded: (-1.2833, 36.8167) -> Kenya
# Reverse geocoded: (-0.8833, 169.5333) -> Kiribati
# Reverse geocoded: (29.3667, 47.96) -> Kuwait
# Reverse geocoded: (42.8731, 74.6003) -> Kyrgyzstan
# Reverse geocoded: (-8.1826, 114.3188) -> Indonesia
# Reverse geocoded: (33.8719, 35.5097) -> Lebanon
# Reverse geocoded: (-29.3167, 27.4833) -> Lesotho
# Reverse geocoded: (6.3106, -10.8047) -> Liberia
# Reverse geocoded: (18.7833, 100.7833) -> Thailand
# Reverse geocoded: (47.1333, 9.5167) -> Liechtenstein
# Reverse geocoded: (54.6833, 25.3167) -> Lithuania
# Reverse geocoded: (49.6117, 6.13) -> Luxembourg
# Reverse geocoded: (-18.9167, 47.5167) -> Madagascar
# Reverse geocoded: (-13.9833, 33.7833) -> Malawi
# Reverse geocoded: (3.1667, 101.7) -> Malaysia
# Reverse geocoded: (6.8833, 73.1) -> Maldives
# Reverse geocoded: (35.8997, 14.5147) -> Malta
# Reverse geocoded: (7.1, 171.3833) -> Marshall Islands
# Reverse geocoded: (18.0864, -15.9753) -> Mauritania
# Reverse geocoded: (-20.1619, 57.4989) -> Mauritius
# Reverse geocoded: (19.4285, -99.1277) -> Mexico
# Reverse geocoded: (6.9167, 158.15) -> Micronesia
# Reverse geocoded: (36.2625, 46.59) -> Iran
# Reverse geocoded: (43.7333, 7.4167) -> Monaco
# Reverse geocoded: (47.9167, 106.9167) -> Mongolia
# Reverse geocoded: (42.4411, 19.2636) -> Montenegro
# Reverse geocoded: (34.0253, -6.8361) -> Morocco
# Reverse geocoded: (-25.9653, 32.5892) -> Mozambique
# Reverse geocoded: (16.7833, 96.1667) -> Myanmar (Burma)
# Reverse geocoded: (-22.5717, 17.0822) -> Namibia
# Reverse geocoded: (39.55, 27.6167) -> Türkiye
# Reverse geocoded: (27.7167, 85.3167) -> Nepal
# Reverse geocoded: (52.374, 4.8897) -> Netherlands
# Reverse geocoded: (-41.3, 174.7833) -> New Zealand
# Reverse geocoded: (12.1508, -86.2683) -> Nicaragua
# Reverse geocoded: (13.5167, 2.1167) -> Niger
# Reverse geocoded: (9.1758, 7.1808) -> Nigeria
# Reverse geocoded: (39.0194, 125.7547) -> North Korea
# Reverse geocoded: (42.0, 21.4333) -> North Macedonia
# Reverse geocoded: (59.9167, 10.75) -> Norway
# Reverse geocoded: (23.6133, 58.5933) -> Oman
# Reverse geocoded: (33.7, 73.1667) -> Pakistan
# Reverse geocoded: (7.3575, 134.5578) -> Palau
# Reverse geocoded: (-11.1833, -67.0833) -> Bolivia
# Reverse geocoded: (8.9667, -79.5333) -> Panama
# Reverse geocoded: (-9.4647, 147.1925) -> Papua New Guinea
# Failed to reverse geocode: (-23.4333, -61.3333)
# Reverse geocoded: (14.6042, 120.9822) -> Philippines
# Reverse geocoded: (38.7167, -9.1333) -> Portugal
# Reverse geocoded: (25.2867, 51.5333) -> Qatar
# Reverse geocoded: (44.4333, 26.1) -> Romania
# Reverse geocoded: (55.7522, 37.6156) -> Russia
# Reverse geocoded: (-1.9536, 30.0606) -> Rwanda
# Reverse geocoded: (17.3, -62.7167) -> Saint Kitts and Nevis
# Reverse geocoded: (13.1333, -61.2167) -> Saint Vincent and the Grenadines
# Reverse geocoded: (-13.8333, -171.7333) -> Samoa
# Reverse geocoded: (43.9333, 12.45) -> San Marino
# Reverse geocoded: (51.25, 3.6333) -> Belgium
# Reverse geocoded: (24.6408, 46.7728) -> Saudi Arabia
# Reverse geocoded: (14.6708, -17.4381) -> Senegal
# Reverse geocoded: (44.804, 20.4651) -> Serbia
# Reverse geocoded: (-4.6167, 55.45) -> Seychelles
# Reverse geocoded: (8.49, -13.2342) -> Sierra Leone
# Reverse geocoded: (1.2931, 103.8558) -> Singapore
# Reverse geocoded: (48.15, 17.1167) -> Slovakia
# Reverse geocoded: (46.0553, 14.5144) -> Slovenia
# Reverse geocoded: (-9.4333, 159.95) -> Solomon Islands
# Reverse geocoded: (2.0667, 45.3667) -> Somalia
# Reverse geocoded: (-25.7469, 28.188) -> South Africa
# Reverse geocoded: (37.5664, 126.9997) -> South Korea
# Reverse geocoded: (40.4, -3.6833) -> Spain
# Reverse geocoded: (6.9319, 79.8478) -> Sri Lanka
# Reverse geocoded: (15.5881, 32.5342) -> Sudan
# Reverse geocoded: (5.8333, -55.1667) -> Suriname
# Reverse geocoded: (59.3333, 18.05) -> Sweden
# Reverse geocoded: (46.9167, 7.4667) -> Switzerland
# Reverse geocoded: (38.56, 68.7739) -> Tajikistan
# Reverse geocoded: (-6.1833, 35.75) -> Tanzania
# Reverse geocoded: (13.75, 100.5167) -> Thailand
# Reverse geocoded: (-8.5586, 125.5736) -> Timor-Leste
# Reverse geocoded: (21.1333, 104.7) -> Vietnam
# Reverse geocoded: (-21.1333, -175.2) -> Tonga
# Reverse geocoded: (10.65, -61.5167) -> Trinidad and Tobago
# Reverse geocoded: (36.8028, 10.1797) -> Tunisia
# Reverse geocoded: (39.9272, 32.8644) -> Türkiye
# Reverse geocoded: (37.95, 58.3833) -> Turkmenistan
# Reverse geocoded: (-8.5167, 179.2167) -> Tuvalu
# Reverse geocoded: (0.3156, 32.5656) -> Uganda
# Reverse geocoded: (50.4333, 30.5167) -> Ukraine
# Reverse geocoded: (24.4667, 54.3667) -> United Arab Emirates
# Reverse geocoded: (51.5171, -0.1062) -> United Kingdom
# Reverse geocoded: (48.0792, -123.0439) -> United States
# Reverse geocoded: (-34.8581, -56.1708) -> Uruguay
# Reverse geocoded: (41.3167, 69.25) -> Uzbekistan
# Reverse geocoded: (-17.7333, 168.3167) -> Vanuatu
# Reverse geocoded: (10.5, -66.9167) -> Venezuela
# Reverse geocoded: (21.0333, 105.85) -> Vietnam
# Reverse geocoded: (15.3547, 44.2067) -> Yemen
# Reverse geocoded: (-15.4167, 28.2833) -> Zambia
# Reverse geocoded: (-17.8178, 31.0447) -> Zimbabwe
#
# Updated DataFrame:
#            country     location_name  latitude  longitude         timezone  \
# 0      Afghanistan             Kabul   34.5200    69.1800       Asia/Kabul
# 1          Albania            Tirana   41.3300    19.8200    Europe/Tirane
# 2          Algeria           Algiers   36.7600     3.0500   Africa/Algiers
# 3          Andorra  Andorra La Vella   42.5000     1.5200   Europe/Andorra
# 4           Angola            Luanda   -8.8400    13.2300    Africa/Luanda
# ...            ...               ...       ...        ...              ...
# 28726    Venezuela           Caracas   10.5000   -66.9167  America/Caracas
# 28727      Vietnam             Hanoi   21.0333   105.8500     Asia/Bangkok
# 28728        Yemen             Sanaa   15.3547    44.2067        Asia/Aden
# 28729       Zambia            Lusaka  -15.4167    28.2833    Africa/Lusaka
# 28730     Zimbabwe            Harare  -17.8178    31.0447    Africa/Harare
#
#        last_updated_epoch      last_updated  temperature_celsius  \
# 0              1715849100  2024-05-16 13:15                 26.6
# 1              1715849100  2024-05-16 10:45                 19.0
# 2              1715849100  2024-05-16 09:45                 23.0
# 3              1715849100  2024-05-16 10:45                  6.3
# 4              1715849100  2024-05-16 09:45                 26.0
# ...                   ...               ...                  ...
# 28726          1728639900  2024-10-11 05:45                 18.4
# 28727          1728639900  2024-10-11 16:45                 30.1
# 28728          1728639900  2024-10-11 12:45                 21.6
# 28729          1728639900  2024-10-11 11:45                 27.5
# 28730          1728639900  2024-10-11 11:45                 25.2
#
#        temperature_fahrenheit condition_text  ...  air_quality_gb-defra-index  \
# 0                        79.8  Partly Cloudy  ...                           1
# 1                        66.2  Partly cloudy  ...                           1
# 2                        73.4          Sunny  ...                           1
# 3                        43.3  Light drizzle  ...                           1
# 4                        78.8  Partly cloudy  ...                          10
# ...                       ...            ...  ...                         ...
# 28726                    65.2          Clear  ...                           3
# 28727                    86.2  Partly cloudy  ...                          10
# 28728                    70.9          Sunny  ...                           2
# 28729                    81.6          Sunny  ...                           1
# 28730                    77.3          Sunny  ...                           2
#
#         sunrise    sunset  moonrise     moonset      moon_phase  \
# 0      04:50 AM  06:50 PM  12:12 PM    01:11 AM  Waxing Gibbous
# 1      05:21 AM  07:54 PM  12:58 PM    02:14 AM  Waxing Gibbous
# 2      05:40 AM  07:50 PM  01:15 PM    02:14 AM  Waxing Gibbous
# 3      06:31 AM  09:11 PM  02:12 PM    03:31 AM  Waxing Gibbous
# 4      06:12 AM  05:55 PM  01:17 PM    12:38 AM  Waxing Gibbous
# ...         ...       ...       ...         ...             ...
# 28726  06:16 AM  06:12 PM  01:41 PM    12:29 AM  Waxing Gibbous
# 28727  05:51 AM  05:36 PM  01:08 PM  No moonset  Waxing Gibbous
# 28728  05:54 AM  05:45 PM  01:10 PM  No moonset  Waxing Gibbous
# 28729  05:42 AM  06:05 PM  12:13 PM    12:49 AM  Waxing Gibbous
# 28730  05:30 AM  05:56 PM  11:56 AM    12:43 AM  Waxing Gibbous
#
#        moon_illumination                                  agrofood_category  \
# 0                     55  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 1                     55  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 2                     55  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 3                     55  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 4                     55  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# ...                  ...                                                ...
# 28726                 52  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 28727                 52  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 28728                 52  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 28729                 52  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
# 28730                 52  Diverse crops (e.g., Corn, Lentils, Beans, Buc...
#
#        update_count  corrected_country
# 0                 1        Afghanistan
# 1                 1            Albania
# 2                 1            Algeria
# 3                 1            Andorra
# 4                 1             Angola
# ...             ...                ...
# 28726             1          Venezuela
# 28727             1            Vietnam
# 28728             1              Yemen
# 28729             1             Zambia
# 28730             1           Zimbabwe
#
# [28731 rows x 44 columns]

# %%
df['country'] = df['corrected_country']
df['country'].unique()

df.drop(columns=['corrected_country'], inplace=True)  # Deletes 'column_name' from df

output_file = 'AgroFoodEnhancedClimateDataCorrected.csv'
df.to_csv(output_file, index=False)

# %% [markdown]
# unique capitals

# %%
import pandas as pd

# Load your dataset
file_path = r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv"
data = pd.read_csv(file_path)

# Define the replacements in a dictionary
replacements = {
    'Beijing Shi': 'Beijing',
    'Bogot': 'Bohot',
    'Felidhoo': 'Fulidhoo',
    'Kuwait': 'Kuwait City',
    'Mexico': 'Mexico City',
    "Nuku`Aloia": "Nuku'alofa",
    'Phnum Penh': 'Phnom Penh',
    '-Kingdom' : 'Gülşehir', 
    "'S Gravenjansdyk": "'S Gravenjansdijk"
}

# Replace the values in the location_name column
data['location_name'] = data['location_name'].replace(replacements)

# Save the modified DataFrame back to a CSV file (optional)
data.to_csv(file_path, index=False)

print("Replacement completed successfully!")
# Out:
# Replacement completed successfully!

# %% [markdown]
# Adding agrofood column

# %%
import pandas as pd

# Load the weather data CSV file
file_path = r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv"
weather_data = pd.read_csv(file_path)

# Expand the agro-food categories to include more products, especially cereals and diverse crops
def enhanced_agrofood_diversity(temp, humidity, wind_speed, air_quality_pm25):
    if temp > 35 and humidity < 30 and wind_speed > 15 and air_quality_pm25 < 20:
        return 'Desert crops (e.g., Cactus, Date Palms, Quinoa)'
    elif 30 < temp <= 35 and humidity < 60 and wind_speed < 10 and air_quality_pm25 < 50:
        return 'Hot, dry crops (e.g., Olives, Grapes, Barley, Sorghum)'
    elif 20 < temp <= 30 and humidity > 60 and wind_speed <= 5 and air_quality_pm25 < 50:
        return 'Warm, humid crops (e.g., Rice, Cocoa, Mangoes, Soybeans)'
    elif temp <= 20 and humidity > 70 and wind_speed < 5 and air_quality_pm25 < 25:
        return 'Cool-weather crops (e.g., Cabbage, Peas, Strawberries, Oats)'
    elif temp < 10 and humidity > 60 and wind_speed < 5 and air_quality_pm25 < 10:
        return 'Cold-climate crops (e.g., Kale, Brussels Sprouts, Rye, Wheat)'
    else:
        return 'Diverse crops (e.g., Corn, Lentils, Beans, Buckwheat)'

# Apply the new categorization to diversify agro-food products
weather_data['agrofood_category'] = weather_data.apply(
    lambda row: enhanced_agrofood_diversity(row['temperature_celsius'], row['humidity'], row['wind_kph'], row['air_quality_PM2.5']), axis=1
)

# Count the occurrences of last_updated by location
last_updated_counts = weather_data.groupby(['location_name', 'last_updated']).size().reset_index(name='update_count')

# Merge the count with the original data
merged_data = pd.merge(weather_data, last_updated_counts, on=['location_name', 'last_updated'], how='left')

# Save the updated data with more variety in agro-food products
merged_data.to_csv(file_path, index=False)

print(f"Data saved to {file_path}")
# Out:
# Data saved to AgroFoodEnhancedClimateData.csv

# %% [markdown]
# Adding HI WCI  columns

# %%
import pandas as pd
import numpy as np

# Load the dataset
file_path = r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv"
weather_data = pd.read_csv(file_path)

# Function to calculate relative humidity given temperature and dew point
def calculate_heat_index(temp_celsius, humidity):
    # Convert Celsius to Fahrenheit
    fahrenheit = (temp_celsius * 9 / 5) + 32

    # Calculate the squares and cubes of temperature and humidity for the formula
    T2 = fahrenheit ** 2
    T3 = fahrenheit ** 3
    H2 = humidity ** 2
    H3 = humidity ** 3

    # Coefficients for the calculation
    C3 = [
        16.923, 0.185212, 5.37941, -0.100254, 0.00941695, 0.00728898,
        0.000345372, -0.000814971, 0.0000102102, -0.000038646,
        0.0000291583, 0.00000142721, 0.000000197483, -0.0000000218429,
        0.000000000843296, -0.0000000000481975
    ]

    # Calculate the heat index in Fahrenheit using the formula
    heatindex_f = (C3[0] + (C3[1] * fahrenheit) + (C3[2] * humidity) +
                   (C3[3] * fahrenheit * humidity) + (C3[4] * T2) +
                   (C3[5] * H2) + (C3[6] * T2 * humidity) +
                   (C3[7] * fahrenheit * H2) + (C3[8] * T2 * H2) +
                   (C3[9] * T3) + (C3[10] * H3) + (C3[11] * T3 * humidity) +
                   (C3[12] * fahrenheit * H3) + (C3[13] * T3 * H2) +
                   (C3[14] * T2 * H3) + (C3[15] * T3 * H3))

    # Convert the result back to Celsius
    heatindex_c = (heatindex_f - 32) * 5 / 9
    return round(heatindex_c, 2)

# Wind Chill Index (WCI) calculation formula
def calculate_wind_chill(temp_celsius, wind_kph):
    if temp_celsius <= 10 and wind_kph > 4.8:
        WCI = (13.12 + 0.6215 * temp_celsius - 11.37 * wind_kph**0.16 + 
               0.3965 * temp_celsius * wind_kph**0.16)
        return WCI
    else:
        return temp_celsius  



weather_data['Wind Chill Index (C)'] = weather_data.apply(
    lambda row: calculate_wind_chill(row['temperature_celsius'], row['wind_kph']), axis=1)



weather_data['Heat Index (C)'] = weather_data.apply(
    lambda row: calculate_heat_index(row['temperature_celsius'], row['humidity']), axis=1)

# Insert the Heat Index column after a specific column, e.g., 'agrofood_category'
column_position = weather_data.columns.get_loc('agrofood_category') + 1
weather_data.insert(column_position, 'Heat Index (C)', weather_data.pop('Heat Index (C)'))

# Save the updated dataset
output_file = 'AgroFoodEnhancedClimateDataCorrected.csv'
weather_data.to_csv(output_file, index=False)

print(f"Data with Heat Index, Wind Chill Index, and Cloud Cover saved to {output_file}")
# Out:
# Data with Heat Index, Wind Chill Index, and Cloud Cover saved to AgroFoodEnhancedClimateDataCorrected.csv

# %%
import pandas as pd

# Define the file path
file_path = r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Convert the 'last_updated' column to datetime
df['last_updated'] = pd.to_datetime(df['last_updated'])

# Separate the date and time into two different columns
df['date'] = df['last_updated'].dt.date
df['time'] = df['last_updated'].dt.time

df.drop(columns=['update_count'], inplace=True)  # Deletes 'column_name' from df

# Save the modified DataFrame back to the CSV file
df.to_csv(file_path, index=False)

# Print a message to confirm the process is complete
print("Date and time columns added successfully.")

# %% [markdown]
# Adding Disaster column

# %%
import pandas as pd

# Load your dataset
file_path = r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv"
data = pd.read_csv(file_path)

# Define disaster conditions based on the parameters
def assign_disaster(row):
    if row['temperature_celsius'] > 35:
        return 'Heatwave'
    elif row['temperature_celsius'] < 0:
        return 'Cold Wave'
    elif row['wind_kph'] > 150:
        return 'Tornado'
    elif row['wind_kph'] > 120:
        return 'Hurricane'
    elif row['wind_kph'] > 60:
        if row['precip_mm'] > 100:
            return 'Tropical Cyclone'
        return 'Storm'
    elif row['precip_mm'] > 200:
        return 'Monsoon'
    elif row['precip_mm'] > 150:
        return 'Landslide'
    elif row['precip_mm'] > 100:
        return 'Flood'
    elif row['precip_mm'] < 1:
        return 'Drought'
    elif row['air_quality_PM2.5'] > 250:
        return 'Air Quality Disaster'
    elif row['uv_index'] > 8:
        return 'Extreme UV Radiation'
    elif row['temperature_celsius'] < -5 and row['wind_kph'] > 40:
        return 'Blizzard'
    elif row['wind_kph'] > 60 and 'Desert' in row['location_name']:  # Assuming arid region names
        return 'Sandstorm'
    elif row['wind_kph'] > 60 and 0 < row['temperature_celsius'] < 10:
        return 'Hailstorm'
    elif row['visibility_km'] < 1:
        return 'Extreme Fog'
    else:
        return 'No Disaster'

# Apply the function to create a new 'Disaster' column
data['Disaster'] = data.apply(assign_disaster, axis=1)

# Save the updated dataset with the 'Disaster' column
data.to_csv("AgroFoodEnhancedClimateDataCorrected.csv", index=False)

# Display a sample of the updated data with the new Disaster column
print(data[['country', 'location_name', 'temperature_celsius', 'wind_kph', 'precip_mm', 'air_quality_PM2.5', 'uv_index', 'Disaster']].head())
# Out:
#        country     location_name  temperature_celsius  wind_kph  precip_mm  \
# 0  Afghanistan             Kabul                 26.6      13.3        0.0
# 1      Albania            Tirana                 19.0      11.2        0.1
# 2      Algeria           Algiers                 23.0      15.1        0.0
# 3      Andorra  Andorra La Vella                  6.3      11.9        0.3
# 4       Angola            Luanda                 26.0      13.0        0.0
#
#    air_quality_PM2.5  uv_index Disaster
# 0                8.4       7.0  Drought
# 1                1.1       5.0  Drought
# 2               10.4       5.0  Drought
# 3                0.7       2.0  Drought
# 4              183.4       8.0  Drought

# %% [markdown]
# Adding Air Pollution level and Category

# %%
import pandas as pd
import numpy as np

# Load the dataset containing air pollution parameters
df = pd.read_csv(r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv")

# Normalizing the data (min-max scaling) for air_quality_PM2.5, air_quality_PM10, air_quality_Nitrogen_dioxide, air_quality_Carbon_Monoxide, air_quality_Ozone
df['PM2.5_norm'] = (df['air_quality_PM2.5'] - df['air_quality_PM2.5'].min()) / (df['air_quality_PM2.5'].max() - df['air_quality_PM2.5'].min())
df['PM10_norm'] = (df['air_quality_PM10'] - df['air_quality_PM10'].min()) / (df['air_quality_PM10'].max() - df['air_quality_PM10'].min())
df['NO2_norm'] = (df['air_quality_Nitrogen_dioxide'] - df['air_quality_Nitrogen_dioxide'].min()) / (df['air_quality_Nitrogen_dioxide'].max() - df['air_quality_Nitrogen_dioxide'].min())
df['CO_norm'] = (df['air_quality_Carbon_Monoxide'] - df['air_quality_Carbon_Monoxide'].min()) / (df['air_quality_Carbon_Monoxide'].max() - df['air_quality_Carbon_Monoxide'].min())
df['O3_norm'] = (df['air_quality_Ozone'] - df['air_quality_Ozone'].min()) / (df['air_quality_Ozone'].max() - df['air_quality_Ozone'].min())

# Calculate the summary air pollution level as a weighted average (adjust weights as needed)
# Example weights for pollutants
# Updated weights based on WHO guidelines
weights = {'PM2.5': 0.5, 'PM10': 0.2, 'NO2': 0.2, 'CO': 0.05, 'O3': 0.05}

# Adding a new column 'air_pollution_level' to summarize pollution level
df['air_pollution_level'] = (weights['PM2.5'] * df['PM2.5_norm'] +
                             weights['PM10'] * df['PM10_norm'] +
                             weights['NO2'] * df['NO2_norm'] +
                             weights['CO'] * df['CO_norm'] +
                             weights['O3'] * df['O3_norm'])

# Optional: Categorize the air pollution levels into categories (Good, Moderate, Unhealthy)
def categorize_aqi(value):
    if value <= 0.2:
        return 'Good'
    elif value <= 0.4:
        return 'Moderate'
    elif value <= 0.6:
        return 'Unhealthy for Sensitive Groups'
    elif value <= 0.8:
        return 'Unhealthy'
    elif value <= 1.0:
        return 'Very Unhealthy'
    else:
        return 'Hazardous'

df['pollution_category'] = df['air_pollution_level'].apply(categorize_aqi)

columns_to_drop = ['PM2.5_norm', 'PM10_norm', 'NO2_norm', 'CO_norm', 'O3_norm']
df.drop(columns=columns_to_drop, inplace=True)

df.to_csv(r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv")

# %% [markdown]
# All parameters correlation matrix

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import textwrap
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from scipy.stats import kendalltau
file_path = r"C:\Users\User\Desktop\Final_project\AgroFoodEnhancedClimateDataCorrected.csv"
df = pd.read_csv(file_path, usecols = [
    'temperature_celsius', 'wind_kph', 'pressure_mb', 'precip_mm', 'humidity', 
    'visibility_km', 'air_quality_PM2.5', 'air_quality_PM10', 
    'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'air_quality_Carbon_Monoxide',  
    'air_quality_Ozone', 'air_quality_Nitrogen_dioxide','air_quality_Sulphur_dioxide', 
    'Wind Chill Index (C)', 'Heat Index (C)', 'uv_index', 'cloud','gust_kph'
])
corr = df.corr(method='kendall')
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
np.fill_diagonal(mask, False)
fig, ax = plt.subplots(figsize=(10,5))
plt.title("Correlation Matrix of Climate Parameters", fontsize=14)

# Generate the heatmap including the mask
heatmap = sns.heatmap(corr,
                      annot=True,
                      annot_kws={"fontsize": 10},
                      fmt='.2f',
                      linewidths=0.5,
                      cmap='RdBu',
                      mask=mask, # the mask has been included here
                      ax=ax)

# Display our plot
plt.show()
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
